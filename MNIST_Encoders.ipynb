# %%
import numpy as np
import os
import sys
import tensorflow as tf

from tensorflow.examples.tutorials.mnist import input_data

def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

PROJECT_ROOT_DIR = "."
CHAPTER_ID = "autoencoders"

def save_fig(fig_id, tight_layout=True):
    path = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID, fig_id + ".png")
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format='png', dpi=300)
    
mnist = input_data.read_data_sets("/tmp/data/")


def plot_image(image, shape=[28, 28]):
    plt.imshow(image.reshape(shape), cmap="Greys", interpolation="nearest")
    plt.axis("off")
    
def plot_multiple_images(images, n_rows, n_cols, pad=2):
    images = images - images.min()  # make the minimum == 0, so the padding looks white
    w,h = images.shape[1:]
    image = np.zeros(((w+pad)*n_rows+pad, (h+pad)*n_cols+pad))
    for y in range(n_rows):
        for x in range(n_cols):
            image[(y*(h+pad)+pad):(y*(h+pad)+pad+h),(x*(w+pad)+pad):(x*(w+pad)+pad+w)] = images[y*n_cols+x]
    plt.imshow(image, cmap="Greys", interpolation="nearest")
    plt.axis("off")
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
reset_graph()

from functools import partial

n_inputs = 28 * 28
n_hidden1 = 500
n_hidden2 = 500
n_hidden3 = 20  # codings
n_hidden4 = n_hidden2
n_hidden5 = n_hidden1
n_outputs = n_inputs
learning_rate = 0.001

initializer = tf.contrib.layers.variance_scaling_initializer()
my_dense_layer = partial(
    tf.layers.dense,
    activation=tf.nn.elu,
    kernel_initializer=initializer)

X = tf.placeholder(tf.float32, [None, n_inputs])
hidden1 = my_dense_layer(X, n_hidden1)
hidden2 = my_dense_layer(hidden1, n_hidden2)
hidden3_mean = my_dense_layer(hidden2, n_hidden3, activation=None)
hidden3_gamma = my_dense_layer(hidden2, n_hidden3, activation=None)
noise = tf.random_normal(tf.shape(hidden3_gamma), dtype=tf.float32)
hidden3 = hidden3_mean + tf.exp(0.5 * hidden3_gamma) * noise
hidden4 = my_dense_layer(hidden3, n_hidden4)
hidden5 = my_dense_layer(hidden4, n_hidden5)
logits = my_dense_layer(hidden5, n_outputs, activation=None)
outputs = tf.sigmoid(logits)

xentropy = tf.nn.sigmoid_cross_entropy_with_logits(labels=X, logits=logits)
reconstruction_loss = tf.reduce_sum(xentropy)
latent_loss = 0.5 * tf.reduce_sum(
    tf.exp(hidden3_gamma) + tf.square(hidden3_mean) - 1 - hidden3_gamma)
loss = reconstruction_loss + latent_loss

optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
training_op = optimizer.minimize(loss)

init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %%
import numpy as np

n_digits = 60
n_epochs = 50
batch_size = 150

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        n_batches = mnist.train.num_examples // batch_size
        for iteration in range(n_batches):
            print("\r{}%".format(100 * iteration // n_batches), end="")
            sys.stdout.flush()
            X_batch, y_batch = mnist.train.next_batch(batch_size)
            sess.run(training_op, feed_dict={X: X_batch})
        loss_val, reconstruction_loss_val, latent_loss_val = sess.run([loss, reconstruction_loss, latent_loss], feed_dict={X: X_batch}) # not shown
        print("\r{}".format(epoch), "Train total loss:", loss_val, "\tReconstruction loss:", reconstruction_loss_val, "\tLatent loss:", latent_loss_val)  # not shown
        saver.save(sess, "./my_model_variational.ckpt")
    
    codings_rnd = np.random.normal(size=[n_digits, n_hidden3])
    outputs_val = outputs.eval(feed_dict={hidden3: codings_rnd})
# Out:
# 0 Train total loss: 17546.768 	Reconstruction loss: 13904.798 	Latent loss: 3641.9692
# 1 Train total loss: 16779.588 	Reconstruction loss: 13168.4 	Latent loss: 3611.187
# 2 Train total loss: 16564.049 	Reconstruction loss: 12763.393 	Latent loss: 3800.6558
# 3 Train total loss: 16322.536 	Reconstruction loss: 12567.961 	Latent loss: 3754.575
# 4 Train total loss: 16294.674 	Reconstruction loss: 12544.149 	Latent loss: 3750.525
# 5 Train total loss: 16505.68 	Reconstruction loss: 12721.205 	Latent loss: 3784.4753
# 6 Train total loss: 16215.546 	Reconstruction loss: 12324.999 	Latent loss: 3890.5466
# 7 Train total loss: 16143.672 	Reconstruction loss: 12384.0 	Latent loss: 3759.6724
# 89% Train total loss: 15918.93 	Reconstruction loss: 12158.182 	Latent loss: 3760.7476
# 99% Train total loss: 15798.068 	Reconstruction loss: 11997.502 	Latent loss: 3800.566
# 10 Train total loss: 15328.795 	Reconstruction loss: 11585.346 	Latent loss: 3743.449
# 11 Train total loss: 15628.723 	Reconstruction loss: 11825.395 	Latent loss: 3803.3276
# 12% Train total loss: 15730.107 	Reconstruction loss: 11892.431 	Latent loss: 3837.6763
# 13% Train total loss: 15550.926 	Reconstruction loss: 11804.538 	Latent loss: 3746.3877
# 14 Train total loss: 15506.55 	Reconstruction loss: 11646.691 	Latent loss: 3859.8586
# 15 Train total loss: 15313.48 	Reconstruction loss: 11624.344 	Latent loss: 3689.1365
# 16 Train total loss: 15459.984 	Reconstruction loss: 11710.162 	Latent loss: 3749.8218
# 17 Train total loss: 15227.002 	Reconstruction loss: 11430.115 	Latent loss: 3796.8872
# 18 Train total loss: 15197.984 	Reconstruction loss: 11552.088 	Latent loss: 3645.897
# 19 Train total loss: 15129.833 	Reconstruction loss: 11376.749 	Latent loss: 3753.0837
# 20 Train total loss: 14777.912 	Reconstruction loss: 11134.986 	Latent loss: 3642.9263
# 21 Train total loss: 15183.029 	Reconstruction loss: 11395.569 	Latent loss: 3787.46
# 22 Train total loss: 15349.988 	Reconstruction loss: 11632.916 	Latent loss: 3717.0723
# 23 Train total loss: 14808.941 	Reconstruction loss: 11127.564 	Latent loss: 3681.3774
# 24 Train total loss: 14763.255 	Reconstruction loss: 11097.843 	Latent loss: 3665.4119
# 25 Train total loss: 15173.249 	Reconstruction loss: 11423.788 	Latent loss: 3749.4612
# 26 Train total loss: 15300.0625 	Reconstruction loss: 11540.299 	Latent loss: 3759.7634
# 27 Train total loss: 15361.052 	Reconstruction loss: 11593.663 	Latent loss: 3767.3887
# 28 Train total loss: 15593.995 	Reconstruction loss: 11832.599 	Latent loss: 3761.3965
# 29 Train total loss: 15141.702 	Reconstruction loss: 11406.334 	Latent loss: 3735.3684
# 30 Train total loss: 14785.01 	Reconstruction loss: 11109.547 	Latent loss: 3675.463
# 31 Train total loss: 15111.463 	Reconstruction loss: 11368.277 	Latent loss: 3743.1855
# 32 Train total loss: 14760.771 	Reconstruction loss: 11160.137 	Latent loss: 3600.635
# 33 Train total loss: 14978.831 	Reconstruction loss: 11309.191 	Latent loss: 3669.6396
# 34 Train total loss: 15467.948 	Reconstruction loss: 11680.523 	Latent loss: 3787.425
# 35 Train total loss: 15003.3125 	Reconstruction loss: 11242.429 	Latent loss: 3760.8838
# 36 Train total loss: 14992.598 	Reconstruction loss: 11336.29 	Latent loss: 3656.308
# 37 Train total loss: 14725.187 	Reconstruction loss: 10985.287 	Latent loss: 3739.8997
# 38 Train total loss: 15429.164 	Reconstruction loss: 11629.586 	Latent loss: 3799.5786
# 39% Train total loss: 14766.226 	Reconstruction loss: 11108.23 	Latent loss: 3657.9949
# 40 Train total loss: 14528.451 	Reconstruction loss: 10911.851 	Latent loss: 3616.6
# 41 Train total loss: 15030.957 	Reconstruction loss: 11348.406 	Latent loss: 3682.5513
# 42 Train total loss: 15001.689 	Reconstruction loss: 11293.836 	Latent loss: 3707.8533
# 43 Train total loss: 14644.158 	Reconstruction loss: 11033.365 	Latent loss: 3610.7935
# 44 Train total loss: 14546.846 	Reconstruction loss: 10898.075 	Latent loss: 3648.77
# 45 Train total loss: 14918.534 	Reconstruction loss: 11234.384 	Latent loss: 3684.1501
# 46 Train total loss: 14037.41 	Reconstruction loss: 10480.719 	Latent loss: 3556.6914
# 47 Train total loss: 14379.609 	Reconstruction loss: 10813.583 	Latent loss: 3566.0266
# 48 Train total loss: 14996.818 	Reconstruction loss: 11355.969 	Latent loss: 3640.8496
# 49 Train total loss: 14798.528 	Reconstruction loss: 11167.359 	Latent loss: 3631.1692

# %%
plt.figure(figsize=(8,50))
for iteration in range(n_digits):
    plt.subplot(n_digits, 10, iteration + 1)
    plot_image(outputs_val[iteration])

# %%
n_rows = 6
n_cols = 10
plot_multiple_images(outputs_val.reshape(-1, 28, 28), n_rows, n_cols)
save_fig("generated_digits_plot")
plt.show()
# Out:
# Saving figure generated_digits_plot

# %%
latent_loss = 0.5 * tf.reduce_sum(
    tf.exp(hidden3_gamma) + tf.square(hidden3_mean) - 1 - hidden3_gamma)

# %%
n_digits = 3
X_test, y_test = mnist.test.next_batch(batch_size)
codings = hidden3

with tf.Session() as sess:
    saver.restore(sess, "./my_model_variational.ckpt")
    codings_val = codings.eval(feed_dict={X: X_test})
# Out:
# INFO:tensorflow:Restoring parameters from ./my_model_variational.ckpt

# %%
with tf.Session() as sess:
    saver.restore(sess, "./my_model_variational.ckpt")
    outputs_val = outputs.eval(feed_dict={codings: codings_val})
# Out:
# INFO:tensorflow:Restoring parameters from ./my_model_variational.ckpt

# %%
fig = plt.figure(figsize=(8, 2.5 * n_digits))
for iteration in range(n_digits):
    plt.subplot(n_digits, 2, 1 + 2 * iteration)
    plot_image(X_test[iteration])
    plt.subplot(n_digits, 2, 2 + 2 * iteration)
    plot_image(outputs_val[iteration])

# %%
n_iterations = 3
n_digits = 6
codings_rnd = np.random.normal(size=[n_digits, n_hidden3])

with tf.Session() as sess:
    saver.restore(sess, "./my_model_variational.ckpt")
    target_codings = np.roll(codings_rnd, -1, axis=0)
    for iteration in range(n_iterations + 1):
        codings_interpolate = codings_rnd + (target_codings - codings_rnd) * iteration / n_iterations
        outputs_val = outputs.eval(feed_dict={codings: codings_interpolate})
        plt.figure(figsize=(11, 1.5*n_iterations))
        for digit_index in range(n_digits):
            plt.subplot(1, n_digits, digit_index + 1)
            plot_image(outputs_val[digit_index])
        plt.show()
# Out:
# INFO:tensorflow:Restoring parameters from ./my_model_variational.ckpt
